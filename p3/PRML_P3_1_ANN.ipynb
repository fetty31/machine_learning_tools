# %% [markdown]
# # PRML Session P3.1 ARTIFICIAL NEURAL NETWORKS
#
# ## Task 1: Analyze the Diabete dataset and try to predict the variable Outcome.
#
# Dataset was initially developed at the National Institute of Diabetes and Digestive and Kidney Diseases. All the patients are females at least 21 yo.
#
# 1) Load the diabetes.csv file and plot data;

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("../data/diabetes.csv")

print(df.head())

import matplotlib.pyplot as plt

plt.figure(figsize=(7,7))
plt.scatter(df["BloodPressure"], df["Age"], c=df["Outcome"])
plt.title("Some data plot")
plt.xlabel("BloodPressure")
plt.ylabel("Age")
plt.show()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# 2) Decide how to handle missing values (if any);

# %%
# Possible imputation strategy
import numpy as np
from sklearn.impute import SimpleImputer

imp = SimpleImputer(missing_values=np.nan, strategy='mean')
for key in df.columns:
    df[key] = imp.fit_transform(df[key].values.reshape(-1,1))

df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0    148.0           72.0           35.0      0.0  33.6
# 1            1.0     85.0           66.0           29.0      0.0  26.6
# 2            8.0    183.0           64.0            0.0      0.0  23.3
# 3            1.0     89.0           66.0           23.0     94.0  28.1
# 4            0.0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0    101.0           76.0           48.0    180.0  32.9
# 764          2.0    122.0           70.0           27.0      0.0  36.8
# 765          5.0    121.0           72.0           23.0    112.0  26.2
# 766          1.0    126.0           60.0            0.0      0.0  30.1
# 767          1.0     93.0           70.0           31.0      0.0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0      1.0
# ...

# %% [markdown]
# 3) Decide if a pre-processing of the data is needed (e.g. dimensionality reduction, data normalization);

# %% [markdown]
# 4) Split the dataset into a training set and a test set.

# %% [markdown]
# 5) Train a neural network with **Keras**. Experiment with different numbers of *hidden layers* and *neurons per layer* to analyze how the architecture affects the model’s performance. Report the configurations you tested, your reasoning behind them, and compare the results using appropriate evaluation metrics.

# %% [markdown]
# 6) As in part 5, train a neural network, but this time try different values for the *learning rate*, *number of epochs*, and *batch size* to study their impact on the training process and model performance.
#
# **Hint:** If you choose a very high number of epochs, make sure to use an EarlyStopping callback to prevent overfitting and unnecessary computation. Evaluate the effect of using EarlyStopping on both the training time and model performance. Discuss whether it helped improve generalization or reduced overfitting.

# %% [markdown]
# ## Task 2: Use historical stock market data from the New York Stock Exchange (NYSE) to train a Recurrent Neural Network (RNN) for time series prediction.
#
# Your goal is to predict future stock prices (e.g., the closing price) based on past values.
#
# 1) Load the price-split-adjusted.csv file and select data for a single company;
#
# **Hint:** Each company has a unique identifier in the *Symbol* column.

# %% [markdown]
# 2) Plot the time serie that you want to predict;

# %% [markdown]
# 3) Normalize the selected time series data to ensure efficient training;
#
# **Hint:** You can use techniques like Min-Max scaling or Standardization.

# %% [markdown]
# 4) Split into train and test sets;

# %% [markdown]
# 5) Decide how many previous days you want to use to predict the value for the current day, and transform the dataset into a set of mini time series (sequences) based on this number of days.

# %% [markdown]
# 6) The RNN expects the input data (X) to be in a specific format: [samples, time steps, features].
#
# Currently, your data is in the format: [samples, features], where each sample represents a single time step. You must reshape the prepared training and testing input data into the expected structure using numpy.reshape().

# %% [markdown]
# 7) Train different models using various RNN architectures such as SimpleRNN, LSTM, or GRU. Evaluate each model's performance using appropriate metrics such as Mean Absolute Error (MAE) or Root Mean Squared Error (RMSE).

# %% [markdown]
# 8) Visualize both the predicted and actual values over time to compare the model's performance and observe how well the predictions match the real stock prices.
